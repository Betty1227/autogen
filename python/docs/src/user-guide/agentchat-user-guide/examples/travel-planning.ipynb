# %%
pip install -U "autogen-agentchat" "autogen-ext[openai,azure]"
# Out:
# Requirement already satisfied: autogen-agentchat in /usr/local/lib/python3.11/dist-packages (0.7.2)
# Collecting autogen-ext[azure,openai]
#   Downloading autogen_ext-0.7.2-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: autogen-core==0.7.2 in /usr/local/lib/python3.11/dist-packages (from autogen-agentchat) (0.7.2)
# Requirement already satisfied: jsonref~=1.1.0 in /usr/local/lib/python3.11/dist-packages (from autogen-core==0.7.2->autogen-agentchat) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.34.1 in /usr/local/lib/python3.11/dist-packages (from autogen-core==0.7.2->autogen-agentchat) (1.36.0)
# Requirement already satisfied: pillow>=11.0.0 in /usr/local/lib/python3.11/dist-packages (from autogen-core==0.7.2->autogen-agentchat) (11.3.0)
# Requirement already satisfied: protobuf~=5.29.3 in /usr/local/lib/python3.11/dist-packages (from autogen-core==0.7.2->autogen-agentchat) (5.29.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in /usr/local/lib/python3.11/dist-packages (from autogen-core==0.7.2->autogen-agentchat) (2.11.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from autogen-core==0.7.2->autogen-agentchat) (4.14.1)
# Collecting azure-ai-inference>=1.0.0b9 (from autogen-ext[azure,openai])
#   Downloading azure_ai_inference-1.0.0b9-py3-none-any.whl.metadata (34 kB)
# Collecting azure-ai-projects>=1.0.0b11 (from autogen-ext[azure,openai])
#   Downloading azure_ai_projects-1.1.0b2-py3-none-any.whl.metadata (23 kB)
# Collecting azure-core (from autogen-ext[azure,openai])
#   Downloading azure_core-1.35.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.0 MB/s eta 0:00:00
# Collecting azure-identity (from autogen-ext[azure,openai])
#   Downloading azure_identity-1.24.0-py3-none-any.whl.metadata (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 5.3 MB/s eta 0:00:00
# Collecting azure-search-documents>=11.4.0 (from autogen-ext[azure,openai])
#   Downloading azure_search_documents-11.5.3-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.11/dist-packages (from autogen-ext[azure,openai]) (24.1.0)
# Requirement already satisfied: openai>=1.93 in /usr/local/lib/python3.11/dist-packages (from autogen-ext[azure,openai]) (1.99.1)
# Requirement already satisfied: tiktoken>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from autogen-ext[azure,openai]) (0.10.0)
# Collecting isodate>=0.6.1 (from azure-ai-inference>=1.0.0b9->autogen-ext[azure,openai])
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting azure-storage-blob>=12.15.0 (from azure-ai-projects>=1.0.0b11->autogen-ext[azure,openai])
#   Downloading azure_storage_blob-12.26.0-py3-none-any.whl.metadata (26 kB)
# Collecting azure-ai-agents>=1.0.0 (from azure-ai-projects>=1.0.0b11->autogen-ext[azure,openai])
#   Downloading azure_ai_agents-1.1.0-py3-none-any.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from azure-core->autogen-ext[azure,openai]) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from azure-core->autogen-ext[azure,openai]) (1.17.0)
# Collecting azure-common>=1.1 (from azure-search-documents>=11.4.0->autogen-ext[azure,openai])
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.93->autogen-ext[azure,openai]) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.93->autogen-ext[azure,openai]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.93->autogen-ext[azure,openai]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.93->autogen-ext[azure,openai]) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.93->autogen-ext[azure,openai]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai>=1.93->autogen-ext[azure,openai]) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken>=0.8.0->autogen-ext[azure,openai]) (2024.11.6)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.11/dist-packages (from azure-identity->autogen-ext[azure,openai]) (43.0.3)
# Collecting msal>=1.30.0 (from azure-identity->autogen-ext[azure,openai])
#   Downloading msal-1.33.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity->autogen-ext[azure,openai])
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai>=1.93->autogen-ext[azure,openai]) (3.10)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=2.5->azure-identity->autogen-ext[azure,openai]) (1.17.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[azure,openai]) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[azure,openai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.93->autogen-ext[azure,openai]) (0.16.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->autogen-ext[azure,openai]) (2.10.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.34.1->autogen-core==0.7.2->autogen-agentchat) (8.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.2->autogen-agentchat) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.2->autogen-agentchat) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.10.0->autogen-core==0.7.2->autogen-agentchat) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core->autogen-ext[azure,openai]) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.21.0->azure-core->autogen-ext[azure,openai]) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=2.5->azure-identity->autogen-ext[azure,openai]) (2.22)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.34.1->autogen-core==0.7.2->autogen-agentchat) (3.23.0)
# Downloading azure_ai_inference-1.0.0b9-py3-none-any.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.9/124.9 kB 9.4 MB/s eta 0:00:00
# Downloading azure_ai_projects-1.1.0b2-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 kB 10.2 MB/s eta 0:00:00
# Downloading azure_core-1.35.0-py3-none-any.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.7/210.7 kB 15.5 MB/s eta 0:00:00
# Downloading azure_search_documents-11.5.3-py3-none-any.whl (298 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.8/298.8 kB 21.1 MB/s eta 0:00:00
# Downloading autogen_ext-0.7.2-py3-none-any.whl (330 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.9/330.9 kB 20.1 MB/s eta 0:00:00
# Downloading azure_identity-1.24.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.9/187.9 kB 13.3 MB/s eta 0:00:00
# Downloading azure_ai_agents-1.1.0-py3-none-any.whl (191 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.1/191.1 kB 12.9 MB/s eta 0:00:00
# Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Downloading azure_storage_blob-12.26.0-py3-none-any.whl (412 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.9/412.9 kB 24.1 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading msal-1.33.0-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 8.2 MB/s eta 0:00:00
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Installing collected packages: azure-common, isodate, azure-core, azure-storage-blob, azure-search-documents, azure-ai-inference, azure-ai-agents, msal, azure-ai-projects, autogen-ext, msal-extensions, azure-identity
# Successfully installed autogen-ext-0.7.2 azure-ai-agents-1.1.0 azure-ai-inference-1.0.0b9 azure-ai-projects-1.1.0b2 azure-common-1.1.28 azure-core-1.35.0 azure-identity-1.24.0 azure-search-documents-11.5.3 azure-storage-blob-12.26.0 isodate-0.7.2 msal-1.33.0 msal-extensions-1.3.1

# %% [markdown]
# # Travel Planning
#
# In this example, we'll walk through the process of creating a sophisticated travel planning system using AgentChat. Our travel planner will utilize multiple AI agents, each with a specific role, to collaboratively create a comprehensive travel itinerary.
#
# First, let us import the necessary modules.

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import OpenAIChatCompletionClient

# %% [markdown]
# ### Defining Agents
#
# In the next section we will define the agents that will be used in the travel planning team.

# %%
model_client = OpenAIChatCompletionClient(
    api_key="AIzaSyCqCYRFR1qkG3bLGZsHrzvE056U_ntn71Q",
    base_url="https://generativelanguage.googleapis.com/v1beta/openai",
    model="gemini-2.5-flash")

planner_agent = AssistantAgent(
    "planner_agent",
    model_client=model_client,
    description="A helpful assistant that can plan trips.",
    system_message="You are a helpful assistant that can suggest a travel plan for a user based on their request.",
)

local_agent = AssistantAgent(
    "local_agent",
    model_client=model_client,
    description="A local assistant that can suggest local activities or places to visit.",
    system_message="You are a helpful assistant that can suggest authentic and interesting local activities or places to visit for a user and can utilize any context information provided.",
)

language_agent = AssistantAgent(
    "language_agent",
    model_client=model_client,
    description="A helpful assistant that can provide language tips for a given destination.",
    system_message="You are a helpful assistant that can review travel plans, providing feedback on important/critical tips about how best to address language or communication challenges for the given destination. If the plan already includes language tips, you can mention that the plan is satisfactory, with rationale.",
)

travel_summary_agent = AssistantAgent(
    "travel_summary_agent",
    model_client=model_client,
    description="A helpful assistant that can summarize the travel plan.",
    system_message="You are a helpful assistant that can take in all of the suggestions and advice from the other agents and provide a detailed final travel plan. You must ensure that the final plan is integrated and complete. YOUR FINAL RESPONSE MUST BE THE COMPLETE PLAN. When the plan is complete and all perspectives are integrated, you can respond with TERMINATE.",
)

# %%
termination = TextMentionTermination("TERMINATE")
group_chat = RoundRobinGroupChat(
    [planner_agent, local_agent, language_agent, travel_summary_agent], termination_condition=termination
)
await Console(group_chat.run_stream(task="Plan a 3 day trip to Nepal."))

await model_client.close()
# Out:
# ---------- TextMessage (user) ----------
# Plan a 3 day trip to Nepal.
# ---------- TextMessage (planner_agent) ----------
# A 3-day trip to Nepal is quite short, meaning you'll need to focus on one primary region to make the most of your time without feeling rushed. The most logical and fulfilling choice for such a brief visit is the **Kathmandu Valley**, as it offers a rich blend of history, culture, spirituality, and incredible UNESCO World Heritage Sites, and is where international flights arrive.
#
# Here's a suggested 3-day itinerary focusing on the Kathmandu Valley, with an option to see the Himalayas:
#
# ---
#
# ## 3-Day Cultural & Spiritual Immersion in Kathmandu Valley
#
# This itinerary assumes your arrival and departure are via Kathmandu's Tribhuvan International Airport (TIA).
#
# **Travel Style:** Fast-paced, cultural exploration, sight-seeing.
#
# ---
#
# ### Day 1: Ancient Wonders & Spiritual Vibes
#
# *   **Morning (Arrival & Check-in):**
#     *   Arrive at Kathmandu's Tribhuvan International Airport (TIA).
#     *   Get a pre-paid taxi or arrange for a hotel pick-up to your accommodation in Thamel (a bustling tourist hub with plenty of hotels, restaurants, and shops).
#     *   Check in, freshen up, and have lunch.
# *   **Afternoon (Swayambhunath & Kathmandu Durbar Square):**
#     *   **Swayambhunath Stupa (Monkey Temple):** Start your exploration with this iconic Buddhist stupa perched on a hill. Enjoy panoramic views of Kathmandu Valley and observe the playful monkeys. It's a great introduction to Nepal's spiritual side.
#     *   **Kathmandu Durbar Square:** Head to the historic heart of Kathmandu. This UNESCO World Heritage site showcases ancient palaces, courtyards, and temples. Witness the Kumari Ghar (House of the Living Goddess), and admire the intricate Newari architecture.
# *   **Evening (Thamel Exploration & Dinner):**
#     *   Wander through the lively streets of Thamel. It's perfect for souvenir shopping, finding local crafts, and soaking in the atmosphere.
#     *   Enjoy dinner at one of Thamel's many restaurants, offering both local Nepali cuisine and international dishes.
#
# ---
#
# ### Day 2: Sacred Sites & Royal Cities
#
# *   **Morning (Pashupatinath & Boudhanath):**
#     *   **Pashupatinath Temple:** Visit Nepal's most sacred Hindu temple complex, situated on the banks of the Bagmati River. Observe Hindu cremation rituals and saffron-clad sadhus (holy men). (Note: Non-Hindus are not permitted inside the main temple, but you can observe from outside).
#     *   **Boudhanath Stupa:** Head to one of the largest stupas in the world and a major pilgrimage site for Tibetan Buddhists. Circumambulate the stupa with pilgrims, spin prayer wheels, and soak in the peaceful, spiritual ambiance.
# *   **Afternoon (Bhaktapur Durbar Square):**
#     *   Take a taxi to **Bhaktapur Durbar Square**, an ancient Newari city that feels like stepping back in time. This well-preserved UNESCO site is famous for its intricate wood carvings, 55-window palace, Golden Gate, and Nyatapola Temple (Nepal's tallest pagoda-style temple). Enjoy a traditional Nepali lunch in Bhaktapur.
# *   **Evening (Cultural Dinner):**
#     *   Return to Kathmandu. Consider experiencing a traditional Nepali dinner with cultural performances, often available in Thamel or nearby areas.
#
# ---
#
# ### Day 3: Himalayan Views & Departure
#
# *   **Option A (Recommended for Himalayan Views): Mountain Flight (Everest Experience):**
#     *   **Early Morning:** Book a scenic **Everest Mountain Flight** (approx. 1 hour). This is the best way to see the towering Himalayas, including Mount Everest, in such a short trip without trekking. Flights usually depart early in the morning from Kathmandu Domestic Airport.
#     *   **Late Morning/Afternoon:** Return to your hotel for breakfast. Depending on your flight time, you can revisit a favorite spot, do some last-minute souvenir shopping, or enjoy a relaxed lunch.
# *   **Option B (Alternative for Views, if no Mountain Flight): Nagarkot Sunrise:**
#     *   **Early Morning:** Arrange a private car to **Nagarkot** (approx. 1.5-2 hours drive from Kathmandu). This hill station offers stunning sunrise views of the Himalayas (weather permitting).
#     *   **Late Morning/Afternoon:** Have breakfast in Nagarkot, then drive back to Kathmandu. You could make a quick stop at **Patan Durbar Square** on the way back for another taste of Newari architecture if time allows, or simply head back to Kathmandu for last-minute activities.
# *   **Evening (Departure):**
#     *   Head to Tribhuvan International Airport (TIA) for your departure. Ensure you allow ample time for traffic and airport procedures.
#
# ---
#
# ### Important Considerations for a 3-Day Trip:
#
# *   **Visa:** Obtain your Nepali visa in advance or upon arrival at TIA (check current requirements for your nationality).
# *   **Connectivity:** Purchase a local SIM card at the airport for easy navigation and communication.
# *   **Currency:** Nepali Rupee (NPR). ATMs are widely available.
# *   **Transportation:** Taxis are the most convenient for getting around the valley. Ride-sharing apps like Pathao and InDrive are also popular. Negotiate fares beforehand if no meter/app is used.
# *   **Attire:** Dress modestly, especially when visiting temples and religious sites. Comfortable walking shoes are essential.
# *   **Food:** Don't miss trying local Nepali dishes like Dal Bhat (lentil soup with rice and curries), momos (dumplings), and Newari cuisine.
# *   **Water:** Drink bottled water only.
# *   **Flexibility:** This is a suggestion. Feel free to adjust based on your interests and energy levels.
# *   **Altitude:** Kathmandu (1,400m / 4,600 ft) is at a moderate altitude; most people don't experience issues, but stay hydrated.
#
# Enjoy your whirlwind trip to the enchanting land of Nepal!
# ---------- TextMessage (local_agent) ----------
#
# ---------- TextMessage (language_agent) ----------
# This is an excellent and well-structured 3-day itinerary for a short trip to Nepal, making the most of the Kathmandu Valley's rich cultural and spiritual offerings. It's realistic given the time constraints and provides good options for experiencing Himalayan views.
#
# Regarding **language and communication challenges**, your plan doesn't explicitly include tips on this, so here's some important feedback to ensure a smooth trip:
#
# While Nepali is the official language, **English is widely understood and spoken in all the tourist areas and establishments you've listed**, including Thamel, hotels, major restaurants, and at the UNESCO World Heritage sites. This means you generally won't face significant communication barriers for most interactions.
#
# However, for a more seamless experience and to handle situations outside the main tourist bubble, here are some critical tips:
#
# ### Addressing Language & Communication Challenges:
#
# 1.  **English Proficiency:**
#     *   **High Proficiency:** Hotels, guesthouses, travel agencies, most restaurants catering to tourists, souvenir shops in Thamel and major sites, and professional guides will have staff who speak good English.
#     *   **Moderate Proficiency:** Many taxi drivers, shopkeepers outside the main tourist areas, and younger, educated individuals will likely have some basic English.
#     *   **Limited Proficiency:** In very local eateries, smaller shops, or with older individuals, English might be very limited or non-existent.
#
# 2.  **Learn Basic Nepali Phrases:** Even a few words go a long way in showing respect and often elicit a warm response.
#     *   **Namaste/Namaskar:** (Nah-mah-stay / Nah-mas-kar) - The traditional greeting, used for hello, goodbye, and sometimes thank you.
#     *   **Dhanyabad:** (Dhan-ya-bad) - Thank you.
#     *   **Hajur:** (Ha-joor) - Yes (polite, used to acknowledge or agree).
#     *   **Ho:** (Ho) - Yes (informal).
#     *   **Chaina:** (Chai-na) - No.
#     *   **Kati ho?:** (Kah-tee ho?) - How much? (useful for shopping/taxis).
#     *   **Ramro chha:** (Ram-ro chha) - It's good/nice.
#
# 3.  **Utilize Translation Apps:**
#     *   Have a translation app like **Google Translate** downloaded on your phone, with the Nepali language pack downloaded for offline use. This is invaluable for communicating with those who speak little to no English, especially for specific requests or in less tourist-centric areas.
#
# 4.  **For Transportation (Taxis/Ride-Sharing):**
#     *   **Taxis:** When hailing a taxi, it's best to show the driver the destination written in Nepali (your hotel can help with this) or show it on a map on your phone. Negotiate the fare *before* getting in, as meters are rarely used. Knowing "Kati ho?" is crucial.
#     *   **Ride-Sharing Apps (Pathao/InDrive):** Your plan rightly mentions these. These apps are excellent as they set the price upfront, reducing the need for negotiation and clearly show the destination on the driver's phone, minimizing language barriers for directions.
#
# 5.  **Visual Communication:**
#     *   Don't hesitate to point, use gestures, or show pictures of what you're looking for (e.g., a specific dish on a menu, an item to buy).
#
# 6.  **Hiring Guides:**
#     *   For the UNESCO World Heritage Sites (Durbar Squares, Pashupatinath, Boudhanath, Swayambhunath), consider hiring a licensed local guide. They are fluent in English (and often other languages) and provide invaluable insights into the history, culture, and religious significance, far beyond what guidebooks offer. This completely bypasses any language issues within the sites themselves.
#
# 7.  **Patience and Politeness:**
#     *   Always approach interactions with patience and a smile. Nepalis are generally very welcoming and helpful, and a polite demeanor will resolve most minor communication hiccups.
#
# In summary, while you won't struggle significantly with English in the main tourist circuit, being prepared with a few Nepali phrases, translation tools, and clear communication strategies (especially for taxis) will enhance your experience and make your short but packed 3-day trip even smoother.
# ---------- TextMessage (travel_summary_agent) ----------
# Here is your complete and integrated 3-day travel plan for Nepal, meticulously designed to maximize your experience in the Kathmandu Valley while addressing all practical considerations, including essential language and communication tips.
#
# ---
#
# ## Final 3-Day Cultural & Spiritual Immersion in Kathmandu Valley, Nepal
#
# This itinerary focuses on the Kathmandu Valley, the arrival point for international flights, ensuring a rich blend of history, culture, spirituality, and a glimpse of the Himalayas, all within a compact timeframe.
#
# **Travel Style:** Fast-paced, cultural exploration, sight-seeing, with a strong emphasis on UNESCO World Heritage Sites.
#
# ### General Travel Information:
#
# *   **Visa:** Obtain your Nepali visa in advance or upon arrival at Tribhuvan International Airport (TIA). Check current requirements for your nationality.
# *   **Connectivity:** Purchase a local SIM card upon arrival at the airport for easy navigation, communication, and using ride-sharing apps.
# *   **Currency:** Nepali Rupee (NPR). ATMs are widely available in Kathmandu and Bhaktapur.
# *   **Water:** Drink only bottled water to avoid stomach issues.
# *   **Attire:** Dress modestly, especially when visiting temples and religious sites. Shoulders and knees should be covered. Comfortable walking shoes are essential as you'll be doing a lot of exploring on foot.
# *   **Food:** Embrace the local cuisine! Don't miss trying Dal Bhat (lentil soup with rice and curries), momos (dumplings), and traditional Newari dishes.
# *   **Altitude:** Kathmandu (1,400m / 4,600 ft) is at a moderate altitude; most people don't experience issues, but staying hydrated is always recommended.
# *   **Flexibility:** This is a suggested itinerary. Feel free to adjust based on your interests, energy levels, and local recommendations.
#
# ---
#
# ### Day 1: Ancient Wonders & Spiritual Vibes
#
# *   **Morning (Arrival & Check-in):**
#     *   Arrive at Kathmandu's Tribhuvan International Airport (TIA).
#     *   Opt for a pre-paid taxi from the airport or arrange for a hotel pick-up to your accommodation in Thamel.
#     *   **Communication Tip:** When using a taxi, it's highly recommended to negotiate the fare *before* getting in. Alternatively, utilize ride-sharing apps like **Pathao** or **InDrive** (download them beforehand), which set the price upfront and display the destination clearly, minimizing communication barriers. Have your hotel address written in Nepali or clearly marked on a map on your phone.
#     *   Check in, freshen up, and have lunch in Thamel.
# *   **Afternoon (Swayambhunath & Kathmandu Durbar Square):**
#     *   **Swayambhunath Stupa (Monkey Temple):** Begin your exploration with this iconic Buddhist stupa perched on a hill. Enjoy panoramic views of Kathmandu Valley and observe the playful monkeys. This is a fantastic introduction to Nepal's spiritual ambiance.
#     *   **Kathmandu Durbar Square:** Head to the historic heart of Kathmandu. This UNESCO World Heritage site showcases ancient palaces, courtyards, and temples. Witness the Kumari Ghar (House of the Living Goddess) and admire the intricate Newari architecture.
#     *   **Communication Tip:** Consider hiring a licensed local guide at these UNESCO sites. They are typically fluent in English and can provide invaluable historical, cultural, and religious insights, enriching your experience far beyond what guidebooks offer and seamlessly bridging any potential language gaps.
# *   **Evening (Thamel Exploration & Dinner):**
#     *   Wander through the lively, vibrant streets of Thamel. It's perfect for souvenir shopping, finding local crafts, and soaking in the bustling atmosphere.
#     *   **Communication Tip:** While English is widely understood in Thamel's tourist shops and restaurants, try using basic Nepali phrases like "**Namaste**" (hello/goodbye) and "**Dhanyabad**" (thank you). When shopping, ask "**Kati ho?**" (How much?). These small efforts are always appreciated by locals.
#     *   Enjoy dinner at one of Thamel's many restaurants, offering a mix of local Nepali cuisine and international dishes.
#
# ### Day 2: Sacred Sites & Royal Cities
#
# *   **Morning (Pashupatinath & Boudhanath):**
#     *   **Pashupatinath Temple:** Visit Nepal's most sacred Hindu temple complex, situated on the banks of the Bagmati River. Observe Hindu cremation rituals and saffron-clad sadhus (holy men). (Note: Non-Hindus are not permitted inside the main temple, but you can observe from outside from designated viewing areas).
#     *   **Boudhanath Stupa:** Proceed to one of the largest stupas in the world and a major pilgrimage site for Tibetan Buddhists. Circumambulate the stupa with pilgrims, spin prayer wheels, and soak in the peaceful, spiritual ambiance.
#     *   **Communication Tip:** Again, a local guide can provide profound context for these deeply religious sites. Pay attention to local customs and traditions, which guides can explain.
# *   **Afternoon (Bhaktapur Durbar Square):**
#     *   Take a taxi to **Bhaktapur Durbar Square**, an ancient Newari city that truly feels like stepping back in time. This remarkably well-preserved UNESCO site is famous for its intricate wood carvings, the 55-window palace, Golden Gate, and Nyatapola Temple (Nepal's tallest pagoda-style temple).
#     *   **Communication Tip:** Ensure you negotiate your taxi fare to Bhaktapur upfront or use a ride-sharing app. Have "Bhaktapur Durbar Square" written down for clarity with the driver. Enjoy a traditional Nepali lunch in Bhaktapur; menus in tourist areas are usually in English.
# *   **Evening (Cultural Dinner):**
#     *   Return to Kathmandu. Consider experiencing a traditional Nepali dinner with cultural performances, often available in Thamel or nearby areas. This is a great way to experience local music and dance.
#
# ### Day 3: Himalayan Views & Departure
#
# *   **Option A (Recommended for Himalayan Views): Mountain Flight (Everest Experience):**
#     *   **Early Morning:** Book a scenic **Everest Mountain Flight** (approx. 1 hour). This is the absolute best way to see the towering Himalayas, including Mount Everest, on such a short trip without requiring a trek. Flights usually depart early in the morning from Kathmandu Domestic Airport. Ensure you pre-book this popular activity to secure your spot.
#     *   **Late Morning/Afternoon:** Return to your hotel for breakfast. Depending on your departure flight time, you can revisit a favorite spot, do some last-minute souvenir shopping, or enjoy a relaxed lunch.
# *   **Option B (Alternative for Views, if no Mountain Flight): Nagarkot Sunrise:**
#     *   **Early Morning:** If a mountain flight isn't feasible, arrange a private car to **Nagarkot** (approx. 1.5-2 hours drive from Kathmandu). This hill station offers stunning sunrise views of the Himalayas (weather permitting).
#     *   **Late Morning/Afternoon:** Have breakfast in Nagarkot, then drive back to Kathmandu. You could make a quick stop at **Patan Durbar Square** on the way back for another taste of Newari architecture if time allows, or simply head back to Kathmandu for last-minute activities.
# *   **Evening (Departure):**
#     *   Head to Tribhuvan International Airport (TIA) for your departure. Ensure you allow ample time for traffic and airport procedures, especially during peak hours.
#
# ---
#
# ### Navigating Language & Communication in Nepal:
#
# While Nepali is the official language, **English is widely understood and spoken in all the primary tourist areas and establishments** you'll encounter on this itinerary, including Thamel, hotels, major restaurants, and at the UNESCO World Heritage Sites. However, being prepared for varying levels of English proficiency and having a few communication strategies will significantly enhance your experience.
#
# 1.  **English Proficiency Levels:**
#     *   **High Proficiency:** Expect good English at hotels, guesthouses, travel agencies, most restaurants catering to tourists, and souvenir shops in Thamel and major sites. Professional guides are also typically fluent.
#     *   **Moderate Proficiency:** Many taxi drivers, shopkeepers outside the main tourist areas, and younger, educated individuals will likely have some basic English.
#     *   **Limited Proficiency:** In very local eateries, smaller shops, or with older individuals, English might be very limited or non-existent.
#
# 2.  **Learn Basic Nepali Phrases:** Even a few words go a long way in showing respect and often elicit a warmer response and better service.
#     *   **Namaste / Namaskar:** (Nah-mah-stay / Nah-mas-kar) - The traditional greeting, used for hello, goodbye, and sometimes thank you.
#     *   **Dhanyabad:** (Dhan-ya-bad) - Thank you.
#     *   **Hajur:** (Ha-joor) - Yes (polite, used to acknowledge or agree).
#     *   **Ho:** (Ho) - Yes (informal).
#     *   **Chaina:** (Chai-na) - No.
#     *   **Kati ho?:** (Kah-tee ho?) - How much? (crucial for shopping/taxis).
#     *   **Ramro chha:** (Ram-ro chha) - It's good/nice.
#
# 3.  **Utilize Translation Apps:**
#     *   Have a translation app like **Google Translate** downloaded on your smartphone. Crucially, download the Nepali language pack for **offline use** so you can use it without an internet connection. This is invaluable for communicating specific requests or in less tourist-centric areas.
#
# 4.  **For Transportation (Taxis/Ride-Sharing):**
#     *   As mentioned, when hailing a taxi, it's best to **show the driver the destination written in Nepali** (your hotel can help with this) or clearly show it on a map on your phone. Always **negotiate the fare beforehand**, as meters are rarely used.
#     *   **Ride-Sharing Apps (Pathao/InDrive):** These are highly recommended. They set the price upfront, reducing the need for negotiation, and clearly show the destination on the driver's phone, significantly minimizing language barriers for directions.
#
# 5.  **Visual Communication:**
#     *   Don't hesitate to point, use gestures, or show pictures of what you're looking for (e.g., a specific dish on a menu, an item to buy). Most Nepalis are intuitive and helpful.
#
# 6.  **Hiring Guides:**
#     *   For the UNESCO World Heritage Sites (Durbar Squares, Pashupatinath, Boudhanath, Swayambhunath), consider hiring a licensed local guide. They are fluent in English (and often other languages) and provide invaluable insights into the history, culture, and religious significance, far beyond what guidebooks offer. This completely bypasses any language issues within the sites themselves.
#
# 7.  **Patience and Politeness:**
#     *   Always approach interactions with patience, a smile, and a respectful demeanor. Nepalis are generally very welcoming and helpful, and a polite approach will resolve most minor communication hiccups easily.
#
# ---
#
# Enjoy your whirlwind, yet incredibly enriching, journey through the enchanting land of Nepal!
#
# TERMINATE
